# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/student_data.csv")
df.head()
# Out:
#    attendance_percentage  assignment_completion_rate  internal_marks  \
# 0              62.472407                   42.959305       48.319398
# 1              97.042858                   67.933066       47.288516
# 2              83.919637                   91.106209       93.437821
# 3              75.919509                   81.255742       47.468234
# 4              49.361118                   86.459280       49.036481
#
#    study_hours_per_week  previous_gpa  participation_score  risk_label
# 0             28.544605      7.431975             4.542720           1
# 1             32.883849      8.832594             5.260921           0
# 2             13.766376      8.560966             8.690927           0
# 3             26.870593      4.923399             4.060039           1
# 4             25.011109      4.895497             8.826847           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   attendance_percentage       1000 non-null   float64
#  1   assignment_completion_rate  1000 non-null   float64
#  2   internal_marks              1000 non-null   float64
#  3   study_hours_per_week        1000 non-null   float64
#  4   previous_gpa                1000 non-null   float64
#  5   participation_score         1000 non-null   float64
#  6   risk_label                  1000 non-null   int64
# dtypes: float64(6), int64(1)
# memory usage: 54.8 KB

# %%
df.describe()
# Out:
#        attendance_percentage  assignment_completion_rate  internal_marks  \
# count            1000.000000                 1000.000000     1000.000000
# mean               69.415393                   65.491211       65.168401
# std                17.528242                   20.453293       20.347194
# min                40.277921                   30.225278       30.000814
# 25%                54.158396                   46.875199       48.294568
# 50%                69.808443                   66.311373       65.042974
# 75%                84.659175                   83.232554       83.137247
# max                99.983060                   99.958961       99.847460
#
#        study_hours_per_week  previous_gpa  participation_score   risk_label
# count           1000.000000   1000.000000          1000.000000  1000.000000
# mean              22.163127      6.964632             5.486180     0.535000
# std               10.027127      1.720860             2.602753     0.499023
# min                5.022869      4.000184             1.055654     0.000000
# 25%               13.466527      5.469844             3.244420     0.000000
# 50%               21.949775      6.967589             5.413625     1.000000
# 75%               30.813928      8.439961             7.658666     1.000000
# max               39.984520      9.986496             9.994153     1.000000

# %%
df.isnull().sum()
# Out:
# attendance_percentage         0
# assignment_completion_rate    0
# internal_marks                0
# study_hours_per_week          0
# previous_gpa                  0
# participation_score           0
# risk_label                    0
# dtype: int64

# %%
df.hist(figsize=(12,8))
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.imshow(df.corr(), interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(df.columns)), df.columns, rotation=90)
plt.yticks(range(len(df.columns)), df.columns)
plt.show()

# %%
df["risk_label"].value_counts()
# Out:
# risk_label
# 1    535
# 0    465
# Name: count, dtype: int64
